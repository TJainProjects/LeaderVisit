# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = "/content/drive/MyDrive/GlobalChinaMapping/WhoWhenWhereDataset.xlsx"

df_one = pd.read_excel(file_path, sheet_name = 'Dataset')
df_one.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-944819bd2625> in <cell line: 0>()
#       1 file_path = "/content/drive/MyDrive/GlobalChinaMapping/LeaderVisitsMapping/AllExcelData/AllData.xlsx"
#       2
# ----> 3 df_one = pd.read_excel(file_path, sheet_name = 'Dataset')
#       4 df_one.head()
#
# NameError: name 'pd' is not defined

# %%
df_one['Original Source'] = 'Central European Institute of Asian Studies (CEIAS)'
df_one.head()
# Out:
#    Year        Name      Level       Country Continent  Developed country  \
# 0  1949  Mao Zedong  President  Soviet Union    Europe                  0
# 1  1950  Zhou Enlai    Premier  Soviet Union    Europe                  0
# 2  1952  Zhou Enlai    Premier  Soviet Union    Europe                  0
# 3  1954  Zhou Enlai    Premier       Myanmar      Asia                  0
# 4  1954  Zhou Enlai    Premier         India      Asia                  0
#
#    Communist country  Developing country  \
# 0                  1                   0
# 1                  1                   0
# 2                  1                   0
# 3                  0                   1
# 4                  0                   1
#
#                                      Original Source
# 0  Central European Institute of Asian Studies (C...
# 1  Central European Institute of Asian Studies (C...
# 2  Central European Institute of Asian Studies (C...
# 3  Central European Institute of Asian Studies (C...
# ...

# %%
file_path = "/content/drive/MyDrive/GlobalChinaMapping/WikipediaVisits_Xi.xlsx"

# %%
df_two = pd.read_excel(file_path)
df_two.head()
# Out:
#    Year       Country                                               Text  \
# 0  2020       Myanmar  State visit. Met PresidentWin Myint, State Cou...
# 1  2022    Kazakhstan  State visit. Xi's first visit outside China si...
# 2  2022     Indonesia  Attendance to the17th G20 summit. Met numerous...
# 3  2022  Saudi Arabia  State visit and attendance to theChina-Arab St...
# 4  2023        Russia  State visit. Second meeting with Putin after t...
#
#          Name                                              Level Continent  \
# 0  Xi Jinping  President of the People's Republic of China; G...      Asia
# 1  Xi Jinping  President of the People's Republic of China; G...      Asia
# 2  Xi Jinping  President of the People's Republic of China; G...      Asia
# 3  Xi Jinping  President of the People's Republic of China; G...      Asia
# 4  Xi Jinping  President of the People's Republic of China; G...    Europe
#
#    Developed country  Communist country  Developing country  \
# ...

# %%
file2= "/content/drive/MyDrive/GlobalChinaMapping/WikipediaVisits_LiK.xlsx"
file3= "/content/drive/MyDrive/GlobalChinaMapping/WikipediaVisits_Li_Qiang.xlsx"
file4 ="/content/drive/MyDrive/GlobalChinaMapping/UpdatedWhoWhenWhereDataset.xlsx"

# %%
df_three= pd.read_excel(file2)
df_four = pd.read_excel(file3)
df_five = pd.read_excel(file4)

# %%
df_comb = pd.concat([df_one, df_two,df_three,df_four,df_five], ignore_index=True)

df_comb.head()
# Out:
#      Year        Name      Level       Country Continent  Developed country  \
# 0  1949.0  Mao Zedong  President  Soviet Union    Europe                  0
# 1  1950.0  Zhou Enlai    Premier  Soviet Union    Europe                  0
# 2  1952.0  Zhou Enlai    Premier  Soviet Union    Europe                  0
# 3  1954.0  Zhou Enlai    Premier       Myanmar      Asia                  0
# 4  1954.0  Zhou Enlai    Premier         India      Asia                  0
#
#    Communist country  Developing country  \
# 0                  1                   0
# 1                  1                   0
# 2                  1                   0
# 3                  0                   1
# 4                  0                   1
#
#                                      Original Source Text  Dates
# 0  Central European Institute of Asian Studies (C...  NaN    NaN
# 1  Central European Institute of Asian Studies (C...  NaN    NaN
# ...

# %%
# df_comb['Year'].sort()

# %%
df_comb.to_excel("/content/drive/MyDrive/GlobalChinaMapping/LeaderVisitsMapping/AllExcelData/AllData.xlsx", index=False)
